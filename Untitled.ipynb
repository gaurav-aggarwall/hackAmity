# %%
import tensorflowjs as tfjs
from tensorflowjs.converters import converter
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-481382e44067> in <module>
# ----> 1 import tensorflowjs as tfjs
#       2 from tensorflowjs.converters import converter
#
# C:\Anaconda3\lib\site-packages\tensorflowjs\__init__.py in <module>
#      19
#      20 # pylint: disable=unused-imports
# ---> 21 from tensorflowjs import converters
#      22 from tensorflowjs import quantization
#      23 from tensorflowjs import version
#
# C:\Anaconda3\lib\site-packages\tensorflowjs\converters\__init__.py in <module>
#      20 # pylint: disable=unused-imports,line-too-long
#      21 from tensorflowjs.converters.keras_h5_conversion import save_keras_model
# ---> 22 from tensorflowjs.converters.keras_tfjs_loader import deserialize_keras_model
#      23 from tensorflowjs.converters.keras_tfjs_loader import load_keras_model
# ...

# %%
#converter.dispatch_keras_h5_to_tensorflowjs_conversion('/home/priyam/Desktop/hackAmity/bts_trial/ResUnet.03_1.449.h5',output_dir='/home/priyam/Desktop')


converter.dispatch_keras_h5_to_tensorflowjs_conversion('C:/Users/Vasudev/Desktop/mammo_result_weights.best.hdf5',output_dir='C:/Users/Vasudev/Desktop/model_mamm/')
# Out:
# (None,
#  [[{'data': array([[[[ 0.18910208,  0.16556954,  0.03405267, ..., -0.01347114,
#               -0.1800231 , -0.14006536],
#              [-0.14894448,  0.06713536,  0.07801845, ...,  0.06745151,
#                0.11589046, -0.27535164],
#              [ 0.25096786,  0.11851655,  0.48159415, ..., -0.15028238,
#               -0.13352281,  0.3528381 ],
#              [-0.21029286, -0.10159256,  0.04633961, ..., -0.05531381,
#               -0.1463398 ,  0.13128476]],
#
#             [[ 0.22993101,  0.13272637, -0.05515516, ..., -0.00085057,
#                0.13099025, -0.11324688],
#              [-0.0549403 , -0.09641007, -0.13030122, ...,  0.10613425,
#               -0.06243994, -0.0493417 ],
#              [ 0.37146574, -0.05413071,  0.22342472, ..., -0.12410587,
#               -0.14220211,  0.13893528],
#              [-0.19706362, -0.0836239 , -0.10627056, ...,  0.12324596,
#               -0.0301489 , -0.13094258]]],
#
#
# ...
